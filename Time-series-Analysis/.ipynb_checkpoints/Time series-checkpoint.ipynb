# %% [markdown]
# Data source - https://community.tableau.com/docs/DOC-1236
#
# Objective - To Apply ARIMA model
#
# Steps -
#         1. Importing useful libraries
#         2. Geting data and  drop the unncessary columns
#         3. Visualizing the series
#         4. Test for Stationarity
#         5. Decomposing
#         6. plot ACF/PACF and Find Optimal Parameters
#         7. Build ARIMA Model

# %% [markdown]
# # 1. Importing useful libraries

# %%
import pandas as pd
import numpy as np
from statistics import mean
import statsmodels.api as sm
import itertools

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['text.color'] = 'k'

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. Geting data and  drop the unncessary columns

# %%
path = 'file:///C:/Users/AAMIR%20SIDDIQUI/Desktop/DS/tutorial%20and%20files/portfolia/TimeSeries_DataAnalysis/data.csv'
df = pd.read_csv(path,parse_dates=[2],encoding = "ISO-8859-1")

# %%
df.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-08-11  11-11-2016  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-08-11  11-11-2016  Second Class    CG-12520
# 2       3  CA-2016-138688 2016-12-06  16-06-2016  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City    ...     \
# 0      Claire Gute   Consumer  United States    Henderson    ...
# 1      Claire Gute   Consumer  United States    Henderson    ...
# 2  Darrin Van Huff  Corporate  United States  Los Angeles    ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# ...

# %% [markdown]
# Too much irrevent data. We need to clean it.

# %%
df.Category.unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
Office_Supplies = df.loc[df['Category'] == 'Office Supplies'] #our objective is to analyize only "Office Supplies" data.

# %% [markdown]
# This step includes removing columns we do not need, check missing values, aggregate sales by date and so on.

# %%
cols = ['Row ID', 'Order ID', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Quantity', 'Discount', 'Profit']
Office_Supplies.drop(cols, axis=1, inplace=True)

Office_Supplies.isnull().sum()
# Out:
# Order Date    0
# Sales         0
# dtype: int64

# %%
Office_Supplies = Office_Supplies.sort_values('Order Date',ascending=False)

# %%
Office_Supplies= Office_Supplies.groupby('Order Date')['Sales'].sum().reset_index()

# %%
Office_Supplies = Office_Supplies.set_index('Order Date')
Office_Supplies.index
# Out:
# DatetimeIndex(['2014-01-03', '2014-01-04', '2014-01-06', '2014-01-07',
#                '2014-01-08', '2014-01-09', '2014-01-10', '2014-01-11',
#                '2014-01-12', '2014-01-13',
#                ...
#                '2017-12-21', '2017-12-22', '2017-12-23', '2017-12-24',
#                '2017-12-25', '2017-12-26', '2017-12-27', '2017-12-28',
#                '2017-12-29', '2017-12-30'],
#               dtype='datetime64[ns]', name='Order Date', length=1148, freq=None)

# %%
Office_Supplies.head(5)
# Out:
#                Sales
# Order Date
# 2014-01-03   303.216
# 2014-01-04   119.888
# 2014-01-06  2282.530
# 2014-01-07    25.104
# 2014-01-08   184.200

# %%
y = Office_Supplies['Sales'].resample('MS').mean()

# %% [markdown]
# # 3. Visualizing the series

# %%
y.plot(figsize=(15, 6))

plt.show()

# %% [markdown]
# # 4. Test for Stationarity

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean= timeseries.rolling(window=12).mean()
    rolstd= timeseries.rolling(window=12).std()
  
    #Plot rolling statistics:
    plt.figure(figsize=(15, 6))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
test_stationarity(y)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.985490
# p-value                         0.036272
# #Lags Used                      1.000000
# Number of Observations Used    46.000000
# Critical Value (1%)            -3.581258
# Critical Value (5%)            -2.926785
# Critical Value (10%)           -2.601541
# dtype: float64

# %% [markdown]
# More negative ADF Statistic is the more likely we reject H0.ADF Stat is negative and lower, but still above our critical values. p-value is also above 0.05. The data is closer to being stationary.
#
#
# NOTE -  The reason behind shifting of mean and std lines is that take window of 12

# %% [markdown]
# # 5. Decomposing

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(y)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(15, 6))
plt.subplot(411)
plt.plot(y, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %%
y_decompose = residual
y_decompose.dropna(inplace=True)
test_stationarity(y_decompose)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -5.121368
# p-value                         0.000013
# #Lags Used                      9.000000
# Number of Observations Used    26.000000
# Critical Value (1%)            -3.711212
# Critical Value (5%)            -2.981247
# Critical Value (10%)           -2.630095
# dtype: float64

# %% [markdown]
# # 6. Plot ACF/PACF and Find Optimal Parameters

# %%
plot_acf(y_decompose)

# %% [markdown]
# optimal parameter for both is (1,1)

# %% [markdown]
# # 7. Build ARIMA Model

# %%
from sklearn.metrics import mean_squared_error

model_arima = ARIMA(y_decompose,order=(1, 0, 1))
model_arima_fit = model_arima.fit(disp=-1)
predictions= model_arima_fit.forecast(steps=10)[0]

plt.figure(figsize=(15, 6))
plt.plot(y_decompose)
plt.plot(model_arima_fit.fittedvalues,color='red')
plt.title('Accuracy: %.4f'% model_arima_fit.aic)
# Out:
# Text(0.5,1,'Accuracy: 475.8645')
